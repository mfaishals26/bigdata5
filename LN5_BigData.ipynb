# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.11.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.11.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 38.6 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 18.9 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.11.2

# %%
import pymongo

# Ganti dengan connection string MongoDB Atlas Anda
CONNECTION_STRING = "mongodb+srv://username:password@cluster0.wq2ol.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0"
# Cek apakah koneksi berhasil
try:
    client.admin.command('ping')
    print("✅ Koneksi ke MongoDB berhasil!")
except Exception as e:
    print(f"❌ Gagal terhubung ke MongoDB: {e}")
# Out:
# ✅ Koneksi ke MongoDB berhasil!

# %%
client = pymongo.MongoClient(CONNECTION_STRING)
db = client["bigdata"]
collection = db["mahasiswa"]

# %%
db = client["bigdata"]  # Membuat database "bigdata"
collection = db["mahasiswa"]  # Membuat koleksi "mahasiswa"

# Insert data pertama
data_mahasiswa = {
    "nama": "Ali",
    "nim": "12345",
    "jurusan": "Informatika"
}

collection.insert_one(data_mahasiswa)
print("✅ Data mahasiswa berhasil dimasukkan!")
# Out:
# ✅ Data mahasiswa berhasil dimasukkan!

# %%
for mahasiswa in collection.find():
    print(mahasiswa)
# Out:
# {'_id': ObjectId('67cc6c4b478e3b84b015cae5'), 'nama': 'Ali', 'nim': '12345', 'jurusan': 'Informatika'}
# {'_id': ObjectId('67cc7df7478e3b84b015cb07'), 'nama': 'Ali', 'nim': '12345', 'jurusan': 'Informatika'}

# %%
# Pilih database
db = client["TokoOnline"]

# Pilih collection untuk katalog produk
produk_collection = db["KatalogElektronik"]

# %%
produk_list = [
    {"nama": "Laptop ASUS ROG", "kategori": "Elektronik", "harga": 15000000, "stok": 5, "spesifikasi": {"RAM": "16GB", "Processor": "Intel Core i7", "Storage": "512GB SSD"}},
    {"nama": "Smartphone Samsung Galaxy S23", "kategori": "Elektronik", "harga": 12000000, "stok": 10, "spesifikasi": {"RAM": "8GB", "Processor": "Snapdragon 8 Gen 2", "Kamera": "50MP"}},
    {"nama": "Headphone Sony WH-1000XM4", "kategori": "Elektronik", "harga": 4000000, "stok": 15, "spesifikasi": {"Noise_Canceling": True, "Baterai": "30 jam"}},
    {"nama": "Smart TV LG 55 inch", "kategori": "Elektronik", "harga": 8000000, "stok": 8, "spesifikasi": {"Resolusi": "4K", "Smart_TV": True}},
 ]

# Tambahkan ke database
produk_collection.insert_many(produk_list)

print(" Produk berhasil ditambahkan!")
# Out:
#  Produk berhasil ditambahkan!

# %%
for produk in produk_collection.find():
    print(produk)
# Out:
# {'_id': ObjectId('67cc7e2c478e3b84b015cb0c'), 'nama': 'Laptop ASUS ROG', 'kategori': 'Elektronik', 'harga': 15000000, 'stok': 5, 'spesifikasi': {'RAM': '16GB', 'Processor': 'Intel Core i7', 'Storage': '512GB SSD'}}
# {'_id': ObjectId('67cc7e2c478e3b84b015cb0d'), 'nama': 'Smartphone Samsung Galaxy S23', 'kategori': 'Elektronik', 'harga': 12000000, 'stok': 10, 'spesifikasi': {'RAM': '8GB', 'Processor': 'Snapdragon 8 Gen 2', 'Kamera': '50MP'}}
# {'_id': ObjectId('67cc7e2c478e3b84b015cb0e'), 'nama': 'Headphone Sony WH-1000XM4', 'kategori': 'Elektronik', 'harga': 4000000, 'stok': 15, 'spesifikasi': {'Noise_Canceling': True, 'Baterai': '30 jam'}}
# {'_id': ObjectId('67cc7e2c478e3b84b015cb0f'), 'nama': 'Smart TV LG 55 inch', 'kategori': 'Elektronik', 'harga': 8000000, 'stok': 8, 'spesifikasi': {'Resolusi': '4K', 'Smart_TV': True}}

# %%
for produk in produk_collection.find({"kategori": "Elektronik"}):
    print(produk)
# Out:
# {'_id': ObjectId('67cc714f478e3b84b015cae6'), 'nama': 'Laptop ASUS ROG', 'kategori': 'Elektronik', 'harga': 15000000, 'stok': 5, 'spesifikasi': {'RAM': '16GB', 'Processor': 'Intel Core i7', 'Storage': '512GB SSD'}}
# {'_id': ObjectId('67cc714f478e3b84b015cae7'), 'nama': 'Smartphone Samsung Galaxy S23', 'kategori': 'Elektronik', 'harga': 12000000, 'stok': 10, 'spesifikasi': {'RAM': '8GB', 'Processor': 'Snapdragon 8 Gen 2', 'Kamera': '50MP'}}
# {'_id': ObjectId('67cc714f478e3b84b015cae8'), 'nama': 'Headphone Sony WH-1000XM4', 'kategori': 'Elektronik', 'harga': 4000000, 'stok': 15, 'spesifikasi': {'Noise_Canceling': True, 'Baterai': '30 jam'}}
# {'_id': ObjectId('67cc714f478e3b84b015cae9'), 'nama': 'Smart TV LG 55 inch', 'kategori': 'Elektronik', 'harga': 8000000, 'stok': 8, 'spesifikasi': {'Resolusi': '4K', 'Smart_TV': True}}
# {'_id': ObjectId('67cc714f478e3b84b015caf4'), 'nama': 'Rice Cooker Philips', 'kategori': 'Elektronik', 'harga': 600000, 'stok': 10, 'spesifikasi': {'Kapasitas': '1.8L', 'Daya': '400W'}}
# {'_id': ObjectId('67cc714f478e3b84b015caf5'), 'nama': 'Blender Miyako 3in1', 'kategori': 'Elektronik', 'harga': 350000, 'stok': 8, 'spesifikasi': {'Daya': '300W', 'Material': 'Plastik'}}
# {'_id': ObjectId('67cc714f478e3b84b015caf9'), 'nama': 'Power Bank Anker 20000mAh', 'kategori': 'Elektronik', 'harga': 450000, 'stok': 12, 'spesifikasi': {'Kapasitas': '20000mAh', 'Port': 'USB-C'}}
